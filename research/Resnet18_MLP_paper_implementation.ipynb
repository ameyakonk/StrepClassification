# %%
import torch
import torch.nn as nn
from torchvision import models
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split
from PIL import Image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
os.chdir('..')

CSV_DIR = 'data/csv'
IMG_DIR = 'data/cnh_dataset'

# %% [markdown]
# ### Change the labels from string to integers and stratified split the dataset

# %%
## replace Positive as 1 and Negative as 0

df = pd.read_csv(os.path.join(CSV_DIR,'dataset_120.csv'))
df = df.drop(columns=['patient_id'])
mapping_dict = {'Positive': 1, 'Negative': 0}
df['label'] = df['label'].map(mapping_dict)
df.to_csv('updated_dataset_120.csv', index=False)

## split train test dataset in stratified way. Train and test dataset have equal proportion of positives and negatives
imge_path = df.iloc[:, 0]
labels = df.iloc[:, 1]
indices = range(len(df))
train_idx, test_idx = train_test_split(
    indices, 
    test_size=0.3, 
    stratify=labels, 
    random_state=42
)

df.head()

print("Train dataset value counts: ",labels[train_idx].value_counts())
print()
print("Test dataset value counts: ",labels[test_idx].value_counts())
# Out:
# Train dataset value counts:  label
# 0    42
# 1    42
# Name: count, dtype: int64
#
# Test dataset value counts:  label
# 0    18
# 1    18
# Name: count, dtype: int64

# %% [markdown]
# ### Create custom Dataloaders

# %%
class StrepDataset(Dataset):
    def __init__(self, csv, img_dir, transform = None):
        self.data = pd.read_csv(csv)
        self.img_dir = img_dir
        self.transform = transform
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        img_name = os.path.join(self.img_dir, self.data.iloc[idx, 0])
        image = Image.open(img_name).convert("RGB")

        if self.transform:
            image = self.transform(image)
        
        features = torch.tensor(self.data.iloc[idx, 2:9])

        label = torch.tensor(self.data.iloc[idx, 1])

        return image, features, label

# %% [markdown]
# ### Multimodal network with Resnet18 as the CNN(feature extraction) and MLP for the 7 symptoms

# %%
class StrepClassifier(nn.Module):
    def __init__(self, num_features, num_classes=1):
        super(StrepClassifier, self).__init__()
        
        # Image Branch: Pre-trained ResNet18
        resnet = models.resnet18(weights='DEFAULT')

        for param in resnet.parameters():
            param.requires_grad = False
        
        for param in resnet.layer4.parameters():
            param.requires_grad = True
        
        self.image_branch = nn.Sequential(*list(resnet.children())[:-1])

        self.img_projection = nn.Sequential(
            nn.Linear(512, 32),
            nn.BatchNorm1d(32), # Forces features to be learnable
            nn.ReLU()
        )

        # # 2. Feature Branch: Simple MLP for numerical data
        self.feature_branch = nn.Sequential(
            nn.Linear(num_features, 16),
            nn.BatchNorm1d(16),
            nn.ReLU(),
            # nn.Linear(64, 32),
            # nn.ReLU()
        )
        
        # # # 3. Fusion Layer: Combines image embeddings (512) + feature embeddings (32)
        self.classifier = nn.Sequential(
            nn.Linear(32 + 16, 16),
            nn.BatchNorm1d(16),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(16, num_classes), # Output for 2 classes
        )

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, images, features):
        # Process image
        img_out = self.image_branch(images)
        img_out = torch.flatten(img_out, 1) # [batch, 512]
        img_out = self.img_projection(img_out)# [batch, 32]
       
        # Process features
        feat_out = self.feature_branch(features) # [batch, 16]
        
        # # Concatenate branches
        combined = torch.cat((img_out, feat_out), dim=1) # [batch, 48]

        # # # Final classification
        return self.classifier(combined) # [batch, 1]

# %% [markdown]
# ### Apply and Vizualize white balancing on the images.
# ### It ensures accurate representation of the photos by compensating for the color temperature of the light source

# %%
def white_balance(img):

    img = np.array(img).astype(float)

    ## average value of each channel
    avg_red = np.mean(img[:, :, 0])
    avg_green = np.mean(img[:, :, 1])
    avg_blue = np.mean(img[:, :, 2])
    
    # gray value calculation
    avg_gray = (avg_red + avg_green + avg_blue) / 3
    
    # Scaling each channel
    img[:, :, 0] *= (avg_gray / avg_red)
    img[:, :, 1] *= (avg_gray / avg_green)
    img[:, :, 2] *= (avg_gray / avg_blue)
    
    # Clip values to [0, 255]
    img = np.clip(img, 0, 255).astype(np.uint8)     #the factor can cause values to go beyond 255, hence bounding it.
    return Image.fromarray(img)

def visualize_correction(image_path):
    original = Image.open(image_path).convert("RGB")
    
    # white balance function
    corrected = white_balance(original)

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    
    axes[0].imshow(original)
    axes[0].set_title("original")
    axes[0].axis('off')
    
    axes[1].imshow(corrected)
    axes[1].set_title("white balanced")
    axes[1].axis('off')
    
    plt.show()

for idx in range(len(df)):
    img_vis = df.iloc[idx, 0]
    visualize_correction(os.path.join(IMG_DIR, img_vis))
    break

# %% [markdown]
# ### Data preprocessing

# %%
def apply_clahe(img):
    img_np = np.array(img)
    lab = cv2.cvtColor(img_np, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    l = clahe.apply(l)
    lab = cv2.merge((l,a,b))
    return Image.fromarray(cv2.cvtColor(lab, cv2.COLOR_LAB2RGB))

# %% [markdown]
# ### Find mean and standard Deviation of the images for Normalization

# %%
crop_size = 160
resize_img_dim = (224, 224)

transforms_for_stats = transforms.Compose([
    transforms.Lambda(lambda x: white_balance(x)),         ## Fix the blur
    transforms.Lambda(lambda x: apply_clahe(x)),           ## Brighten dark areas
    transforms.CenterCrop(crop_size),                      ## Crop to focus only on the tonsil area, disregard tongue / teeth
    transforms.Resize(resize_img_dim),                     ## based on ResNet-18, the standard input image dim is (224, 224)
    transforms.ToTensor() 
])

## Creating a dataloader to iterate through the data
stats_dataset = StrepDataset(csv='updated_dataset_120.csv', img_dir=IMG_DIR, transform=transforms_for_stats)
stats_loader = torch.utils.data.DataLoader(stats_dataset, batch_size=84, shuffle=False)

def get_dataset_stats(dataloader):
    pixel_sum = torch.zeros(3)
    pixel_squared_sum = torch.zeros(3)
    batches = 0
    
    for img, _, _ in dataloader:
        pixel_sum += torch.mean(img, dim=[0, 2, 3])              ## averages accross [batch, height, width]
        pixel_squared_sum += torch.mean(img**2, dim=[0, 2, 3])   ## squared averages accross [batch, height, width]
        batches += 1

    mean = pixel_sum/batches
    std = (pixel_squared_sum / batches - mean ** 2) ** 0.5        ## std = (E[X**2] - E[x]**2)**0.5
    return mean, std

custom_mean, custom_std = get_dataset_stats(stats_loader)
print(f"Mean: {custom_mean}") 
print(f"Std: {custom_std}")
# Out:
# C:\Users\avk1028\AppData\Local\Temp\ipykernel_48768\684004477.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   features = torch.tensor(self.data.iloc[idx, 2:9])
# Mean: tensor([0.4321, 0.3801, 0.4037])
# Std: tensor([0.1523, 0.1880, 0.1785])

# %% [markdown]
# ### Verify Normalization

# %%
transforms_temp = transforms.Compose([
    transforms.Lambda(lambda x: white_balance(x)),## Fix the blur
    transforms.Lambda(lambda x: apply_clahe(x)),  ## Brighten dark areas
    transforms.CenterCrop((180,224)),             ## Crop to focus only on the tonsil area, disregard tongue / teeth
    transforms.Resize(resize_img_dim),
    transforms.RandomAffine(degrees=15, translate=(0.1, 0.1), scale=(0.9, 1.1)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    # transforms.Normalize(mean = custom_mean, std= custom_std)
])

temp_dataset = StrepDataset(csv='updated_dataset_120.csv', img_dir=IMG_DIR, transform=transforms_temp)
temp_subset = Subset(temp_dataset, test_idx)
temp_loader = DataLoader(temp_subset, batch_size=1, shuffle=True)

for images, features, labels in temp_loader:

    norm = transforms.Normalize(mean = custom_mean, std= custom_std)
    n_img = images.squeeze(0).float()  # (3, 180, 180)
    norm_img = norm(n_img)
    
    print(f"Image shape: {images.shape}")
    print(f"Mean: {images.squeeze().mean([1, 2])}")
    print(f"Std:  {images.squeeze().std([1, 2])}")

    print(labels)
    min_val, max_val = torch.aminmax(images)
    print(min_val, max_val)

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    
    axes[0].imshow(images.squeeze().permute([1, 2, 0]))
    axes[0].set_title("original")
    axes[0].axis('off')
    
    axes[1].imshow(norm_img.permute([1, 2, 0]))
    axes[1].set_title("normalized")
    axes[1].axis('off')
    
    plt.show()
    break
# Out:
# C:\Users\avk1028\AppData\Local\Temp\ipykernel_48768\684004477.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   features = torch.tensor(self.data.iloc[idx, 2:9])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.8373296..3.2551155].
# Image shape: torch.Size([1, 3, 224, 224])
# Mean: tensor([0.3307, 0.2546, 0.2891])
# Std:  tensor([0.1690, 0.1723, 0.1775])
# tensor([0])
# tensor(0.) tensor(0.9922)

# %% [markdown]
# ### Created transforms, Dataloaders for train and test data

# %%
# transforms_train = transforms.Compose([
#     transforms.Lambda(lambda x: white_balance(x)),# 3. Fix the blur
#     # transforms.Lambda(lambda x: extract_throat_roi_otsu(x)),# extract_throat_roi
#     transforms.Lambda(lambda x: apply_clahe(x)),  # 2. Brighten dark areas
#     transforms.CenterCrop(crop_size),                    ## Crop to focus only on the tonsil area, disregard tongue / teeth
#     transforms.Resize(resize_img_dim),
#     # transforms.RandomAffine(degrees=15, translate=(0.1, 0.1), scale=(0.9, 1.1)),
#     transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
#     transforms.ToTensor(),
#     transforms.Normalize(mean = custom_mean, std= custom_std)
# ])

transforms_train = transforms.Compose([
    transforms.Lambda(lambda x: white_balance(x)),
    transforms.Lambda(lambda x: apply_clahe(x)),
    transforms.RandomResizedCrop(resize_img_dim, scale=(0.7, 1.0), ratio=(0.9, 1.1)),
    transforms.RandomRotation(degrees=20),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.05),
    transforms.RandomApply([transforms.GaussianBlur(kernel_size=3)], p=0.3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transforms_test = transforms.Compose([
    transforms.Lambda(lambda x: white_balance(x)),       ## Fix the blur
    transforms.Lambda(lambda x: apply_clahe(x)),         ## Brighten dark areas
    transforms.Resize(resize_img_dim),
    transforms.CenterCrop(crop_size),                    ## Crop to focus only on the tonsil area, disregard tongue / teeth
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

## Created datasets for the train and test data with individual transforms
train_dataset = StrepDataset(csv='updated_dataset_120.csv', img_dir=IMG_DIR, transform=transforms_train)
test_dataset = StrepDataset(csv='updated_dataset_120.csv', img_dir=IMG_DIR, transform=transforms_test)

## Created Subsets for the train and test dataset indices
train_subset = Subset(train_dataset, train_idx)
test_subset = Subset(test_dataset, test_idx)

## Created Dataloaders for the train and test dataset 
train_loader = DataLoader(train_subset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_subset, batch_size=16, shuffle=True)

# %% [markdown]
# ### Train the model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = StrepClassifier(num_features = 7, num_classes = 1).to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001, weight_decay=1e-2)
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-2)
epochs = 50

for epoch in range(epochs):
    model.train()
    
    train_loss = 0.0
    preds_train = 0.0
    correct_train = 0.0
    total_train = 0.0

    for images, features, labels in train_loader:
        images, features, labels = images.to(device), features.to(device), labels.to(device).float()

        optimizer.zero_grad()
        outputs = model(images, features.float()).view(-1) ## [batch_size, 1] -> [batch_size]
        loss = criterion(outputs, labels)
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        optimizer.step()
        train_loss += loss.item()

        preds_train = (outputs > 0).float()
        correct_train += (preds_train == labels).sum().item()
        total_train += labels.size(0)

    train_accuracy = 100 * correct_train / total_train
    print("Epoch:", epoch)
    print("Train loss:", train_loss)
    print(f"Train Acc: {train_accuracy:.2f}%")

    with torch.no_grad(): # Disable gradient calculation to save memory/speed
        val_loss = 0.0
        correct = 0.0
        total = 0.0
        model.eval()
        for images, features, labels in test_loader:
            images, features, labels = images.to(device), features.to(device).float(), labels.to(device).float()
            
            outputs = model(images, features).view(-1)
            val_loss += criterion(outputs, labels).item()
            
            # Convert probabilities to binary predictions (0 or 1)
            preds = (outputs > 0).float()
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    # Print progress
    avg_train_loss = train_loss / len(train_loader)
    avg_val_loss = val_loss / len(test_loader)
    accuracy = 100 * correct / total

    print(f"Epoch [{epoch+1}/{epochs}] "
            f"Train Loss: {avg_train_loss:.4f} | "
            f"Val Loss: {avg_val_loss:.4f} | "
            f"Val Acc: {accuracy:.2f}%")
    print()
# Out:
# C:\Users\avk1028\AppData\Local\Temp\ipykernel_48768\684004477.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   features = torch.tensor(self.data.iloc[idx, 2:9])
# Epoch: 0
# Train loss: 6.6248094737529755
# Train Acc: 50.00%
# Epoch [1/50] Train Loss: 1.1041 | Val Loss: 6.7442 | Val Acc: 50.00%
#
# Epoch: 1
# Train loss: 6.810392439365387
# Train Acc: 52.38%
# Epoch [2/50] Train Loss: 1.1351 | Val Loss: 7.5145 | Val Acc: 50.00%
#
# Epoch: 2
# Train loss: 5.5085428059101105
# Train Acc: 52.38%
# Epoch [3/50] Train Loss: 0.9181 | Val Loss: 5.5740 | Val Acc: 50.00%
#
# Epoch: 3
# Train loss: 5.603066861629486
# Train Acc: 58.33%
# Epoch [4/50] Train Loss: 0.9338 | Val Loss: 3.9526 | Val Acc: 52.78%
#
# Epoch: 4
# Train loss: 4.890393674373627
# Train Acc: 58.33%
# Epoch [5/50] Train Loss: 0.8151 | Val Loss: 1.7385 | Val Acc: 44.44%
#
# Epoch: 5
# Train loss: 3.9788013696670532
# Train Acc: 60.71%
# Epoch [6/50] Train Loss: 0.6631 | Val Loss: 2.5828 | Val Acc: 47.22%
#
# Epoch: 6
# Train loss: 4.189066708087921
# Train Acc: 64.29%
# Epoch [7/50] Train Loss: 0.6982 | Val Loss: 2.0130 | Val Acc: 52.78%
#
# Epoch: 7
# Train loss: 5.08289510011673
# Train Acc: 64.29%
# Epoch [8/50] Train Loss: 0.8471 | Val Loss: 1.2562 | Val Acc: 55.56%
#
# Epoch: 8
# Train loss: 3.5477336049079895
# Train Acc: 63.10%
# Epoch [9/50] Train Loss: 0.5913 | Val Loss: 0.9165 | Val Acc: 55.56%
#
# Epoch: 9
# Train loss: 3.702277034521103
# Train Acc: 69.05%
# Epoch [10/50] Train Loss: 0.6170 | Val Loss: 3.1771 | Val Acc: 47.22%
#
# Epoch: 10
# Train loss: 2.690498471260071
# Train Acc: 76.19%
# Epoch [11/50] Train Loss: 0.4484 | Val Loss: 1.4214 | Val Acc: 52.78%
#
# Epoch: 11
# Train loss: 3.836245894432068
# Train Acc: 70.24%
# Epoch [12/50] Train Loss: 0.6394 | Val Loss: 0.7929 | Val Acc: 69.44%
#
# Epoch: 12
# Train loss: 3.3442665338516235
# Train Acc: 77.38%
# Epoch [13/50] Train Loss: 0.5574 | Val Loss: 1.6285 | Val Acc: 58.33%
#
# Epoch: 13
# Train loss: 2.888110190629959
# Train Acc: 78.57%
# Epoch [14/50] Train Loss: 0.4814 | Val Loss: 2.3338 | Val Acc: 55.56%
#
# Epoch: 14
# Train loss: 3.432561218738556
# Train Acc: 73.81%
# Epoch [15/50] Train Loss: 0.5721 | Val Loss: 1.5470 | Val Acc: 50.00%
#
# Epoch: 15
# Train loss: 3.901843875646591
# Train Acc: 69.05%
# Epoch [16/50] Train Loss: 0.6503 | Val Loss: 0.8778 | Val Acc: 50.00%
#
# Epoch: 16
# Train loss: 3.4000754356384277
# Train Acc: 72.62%
# Epoch [17/50] Train Loss: 0.5667 | Val Loss: 1.4872 | Val Acc: 58.33%
#
# Epoch: 17
# Train loss: 3.2694247364997864
# Train Acc: 77.38%
# Epoch [18/50] Train Loss: 0.5449 | Val Loss: 1.3709 | Val Acc: 41.67%
#
# Epoch: 18
# Train loss: 3.0644069015979767
# Train Acc: 71.43%
# Epoch [19/50] Train Loss: 0.5107 | Val Loss: 1.5093 | Val Acc: 47.22%
#
# Epoch: 19
# Train loss: 3.0561171174049377
# Train Acc: 79.76%
# Epoch [20/50] Train Loss: 0.5094 | Val Loss: 0.8412 | Val Acc: 41.67%
#
# Epoch: 20
# Train loss: 3.5397277176380157
# Train Acc: 75.00%
# Epoch [21/50] Train Loss: 0.5900 | Val Loss: 1.0844 | Val Acc: 38.89%
#
# Epoch: 21
# Train loss: 2.9359015226364136
# Train Acc: 80.95%
# Epoch [22/50] Train Loss: 0.4893 | Val Loss: 0.8559 | Val Acc: 55.56%
#
# Epoch: 22
# Train loss: 3.2346422970294952
# Train Acc: 80.95%
# Epoch [23/50] Train Loss: 0.5391 | Val Loss: 0.6768 | Val Acc: 52.78%
#
# Epoch: 23
# Train loss: 2.463574469089508
# Train Acc: 79.76%
# Epoch [24/50] Train Loss: 0.4106 | Val Loss: 0.6674 | Val Acc: 58.33%
#
# Epoch: 24
# Train loss: 2.8534007370471954
# Train Acc: 71.43%
# Epoch [25/50] Train Loss: 0.4756 | Val Loss: 0.6194 | Val Acc: 58.33%
#
# Epoch: 25
# Train loss: 2.076352834701538
# Train Acc: 88.10%
# Epoch [26/50] Train Loss: 0.3461 | Val Loss: 1.6081 | Val Acc: 55.56%
#
# Epoch: 26
# Train loss: 2.6446504294872284
# Train Acc: 75.00%
# Epoch [27/50] Train Loss: 0.4408 | Val Loss: 0.8159 | Val Acc: 58.33%
#
# Epoch: 27
# Train loss: 2.439652770757675
# Train Acc: 85.71%
# Epoch [28/50] Train Loss: 0.4066 | Val Loss: 0.6539 | Val Acc: 61.11%
#
# Epoch: 28
# Train loss: 3.5082807540893555
# Train Acc: 85.71%
# Epoch [29/50] Train Loss: 0.5847 | Val Loss: 0.7689 | Val Acc: 58.33%
#
# Epoch: 29
# Train loss: 2.460259974002838
# Train Acc: 88.10%
# Epoch [30/50] Train Loss: 0.4100 | Val Loss: 1.0520 | Val Acc: 55.56%
#
# Epoch: 30
# Train loss: 3.5029289424419403
# Train Acc: 77.38%
# Epoch [31/50] Train Loss: 0.5838 | Val Loss: 0.7977 | Val Acc: 44.44%
#
# Epoch: 31
# Train loss: 2.2856570184230804
# Train Acc: 85.71%
# Epoch [32/50] Train Loss: 0.3809 | Val Loss: 0.7667 | Val Acc: 50.00%
#
# Epoch: 32
# Train loss: 3.0099228024482727
# Train Acc: 84.52%
# Epoch [33/50] Train Loss: 0.5017 | Val Loss: 0.6497 | Val Acc: 55.56%
#
# Epoch: 33
# Train loss: 2.399373084306717
# Train Acc: 90.48%
# Epoch [34/50] Train Loss: 0.3999 | Val Loss: 1.2750 | Val Acc: 52.78%
#
# Epoch: 34
# Train loss: 2.005236402153969
# Train Acc: 89.29%
# Epoch [35/50] Train Loss: 0.3342 | Val Loss: 0.7751 | Val Acc: 52.78%
#
# Epoch: 35
# Train loss: 2.955627664923668
# Train Acc: 85.71%
# Epoch [36/50] Train Loss: 0.4926 | Val Loss: 0.7432 | Val Acc: 55.56%
#
# Epoch: 36
# Train loss: 2.4355404376983643
# Train Acc: 83.33%
# Epoch [37/50] Train Loss: 0.4059 | Val Loss: 0.8598 | Val Acc: 47.22%
#
# Epoch: 37
# Train loss: 2.031251221895218
# Train Acc: 90.48%
# Epoch [38/50] Train Loss: 0.3385 | Val Loss: 0.6949 | Val Acc: 55.56%
#
# Epoch: 38
# Train loss: 2.4836347699165344
# Train Acc: 86.90%
# Epoch [39/50] Train Loss: 0.4139 | Val Loss: 0.7488 | Val Acc: 55.56%
#
# Epoch: 39
# Train loss: 2.5781498551368713
# Train Acc: 86.90%
# Epoch [40/50] Train Loss: 0.4297 | Val Loss: 0.7498 | Val Acc: 50.00%
#
# Epoch: 40
# Train loss: 3.9447361826896667
# Train Acc: 86.90%
# Epoch [41/50] Train Loss: 0.6575 | Val Loss: 0.9762 | Val Acc: 52.78%
#
# Epoch: 41
# Train loss: 2.2064112722873688
# Train Acc: 89.29%
# Epoch [42/50] Train Loss: 0.3677 | Val Loss: 1.1971 | Val Acc: 44.44%
#
# Epoch: 42
# Train loss: 1.9584365785121918
# Train Acc: 92.86%
# Epoch [43/50] Train Loss: 0.3264 | Val Loss: 0.9449 | Val Acc: 52.78%
#
# Epoch: 43
# Train loss: 2.221283733844757
# Train Acc: 86.90%
# Epoch [44/50] Train Loss: 0.3702 | Val Loss: 0.7632 | Val Acc: 58.33%
#
# Epoch: 44
# Train loss: 2.0811021476984024
# Train Acc: 86.90%
# Epoch [45/50] Train Loss: 0.3469 | Val Loss: 0.7377 | Val Acc: 52.78%
#
# Epoch: 45
# Train loss: 1.6257866770029068
# Train Acc: 94.05%
# Epoch [46/50] Train Loss: 0.2710 | Val Loss: 0.8727 | Val Acc: 44.44%
#
# Epoch: 46
# Train loss: 2.851339638233185
# Train Acc: 80.95%
# Epoch [47/50] Train Loss: 0.4752 | Val Loss: 0.8715 | Val Acc: 47.22%
#
# Epoch: 47
# Train loss: 1.7632465809583664
# Train Acc: 94.05%
# Epoch [48/50] Train Loss: 0.2939 | Val Loss: 0.7302 | Val Acc: 50.00%
#
# Epoch: 48
# Train loss: 1.8385993540287018
# Train Acc: 91.67%
# Epoch [49/50] Train Loss: 0.3064 | Val Loss: 0.7562 | Val Acc: 47.22%
#
# Epoch: 49
# Train loss: 1.6064496636390686
# Train Acc: 98.81%
# Epoch [50/50] Train Loss: 0.2677 | Val Loss: 0.9116 | Val Acc: 50.00%
