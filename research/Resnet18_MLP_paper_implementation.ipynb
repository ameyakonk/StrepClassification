# %%
import torch
import torch.nn as nn
from torchvision import models
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split
from PIL import Image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
os.chdir('..')

CSV_DIR = 'data/csv'
IMG_DIR = 'data/cnh_dataset'

# %% [markdown]
# ### Change the labels from string to integers and stratified split the dataset

# %%
## replace Positive as 1 and Negative as 0

df = pd.read_csv(os.path.join(CSV_DIR,'dataset_120.csv'))
df = df.drop(columns=['patient_id'])
mapping_dict = {'Positive': 1, 'Negative': 0}
df['label'] = df['label'].map(mapping_dict)
df.to_csv('updated_dataset_120.csv', index=False)

## split train test dataset in stratified way. Train and test dataset have equal proportion of positives and negatives
imge_path = df.iloc[:, 0]
labels = df.iloc[:, 1]
indices = range(len(df))
train_idx, test_idx = train_test_split(
    indices, 
    test_size=0.3, 
    stratify=labels, 
    random_state=42
)

df.head()

print("Train dataset value counts: ",labels[train_idx].value_counts())
print()
print("Test dataset value counts: ",labels[test_idx].value_counts())
# Out:
# Train dataset value counts:  label
# 0    42
# 1    42
# Name: count, dtype: int64
#
# Test dataset value counts:  label
# 0    18
# 1    18
# Name: count, dtype: int64

# %% [markdown]
# ### Create custom Dataloaders

# %%
class StrepDataset(Dataset):
    def __init__(self, csv, img_dir, transform = None):
        self.data = pd.read_csv(csv)
        self.img_dir = img_dir
        self.transform = transform
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        img_name = os.path.join(self.img_dir, self.data.iloc[idx, 0])
        image = Image.open(img_name).convert("RGB")

        if self.transform:
            image = self.transform(image)
        
        features = torch.tensor(self.data.iloc[idx, 2:9])

        label = torch.tensor(self.data.iloc[idx, 1])

        return image, features, label

# %% [markdown]
# ### Multimodal network with Resnet18 as the CNN(feature extraction) and MLP for the 7 symptoms

# %%
class StrepClassifier(nn.Module):
    def __init__(self, num_features, num_classes=1):
        super(StrepClassifier, self).__init__()
        
        # Image Branch: Pre-trained ResNet18
        resnet = models.resnet18(weights='DEFAULT')

        for param in resnet.parameters():
            param.requires_grad = False
        
        for param in resnet.layer4.parameters():
            param.requires_grad = True
        
        self.image_branch = nn.Sequential(*list(resnet.children())[:-1])

        self.img_projection = nn.Sequential(
            nn.Linear(512, 32),
            nn.BatchNorm1d(32), # Forces features to be learnable
            nn.ReLU()
        )

        # # 2. Feature Branch: Simple MLP for numerical data
        self.feature_branch = nn.Sequential(
            nn.Linear(num_features, 16),
            nn.BatchNorm1d(16),
            nn.ReLU(),
            # nn.Linear(64, 32),
            # nn.ReLU()
        )
        
        # # # 3. Fusion Layer: Combines image embeddings (512) + feature embeddings (32)
        self.classifier = nn.Sequential(
            nn.Linear(32 + 16, 16),
            nn.BatchNorm1d(16),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(16, num_classes), # Output for 2 classes
        )

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, images, features):
        # Process image
        img_out = self.image_branch(images)
        img_out = torch.flatten(img_out, 1) # [batch, 512]
        img_out = self.img_projection(img_out)# [batch, 32]
       
        # Process features
        feat_out = self.feature_branch(features) # [batch, 16]
        
        # # Concatenate branches
        combined = torch.cat((img_out, feat_out), dim=1) # [batch, 48]

        # # # Final classification
        return self.classifier(combined) # [batch, 1]

# %% [markdown]
# ### Apply and Vizualize white balancing on the images.
# ### It ensures accurate representation of the photos by compensating for the color temperature of the light source

# %%
def white_balance(img):

    img = np.array(img).astype(float)

    ## average value of each channel
    avg_red = np.mean(img[:, :, 0])
    avg_green = np.mean(img[:, :, 1])
    avg_blue = np.mean(img[:, :, 2])
    
    # gray value calculation
    avg_gray = (avg_red + avg_green + avg_blue) / 3
    
    # Scaling each channel
    img[:, :, 0] *= (avg_gray / avg_red)
    img[:, :, 1] *= (avg_gray / avg_green)
    img[:, :, 2] *= (avg_gray / avg_blue)
    
    # Clip values to [0, 255]
    img = np.clip(img, 0, 255).astype(np.uint8)     #the factor can cause values to go beyond 255, hence bounding it.
    return Image.fromarray(img)

def visualize_correction(image_path):
    original = Image.open(image_path).convert("RGB")
    
    # white balance function
    corrected = white_balance(original)

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    
    axes[0].imshow(original)
    axes[0].set_title("original")
    axes[0].axis('off')
    
    axes[1].imshow(corrected)
    axes[1].set_title("white balanced")
    axes[1].axis('off')
    
    plt.show()

for idx in range(len(df)):
    img_vis = df.iloc[idx, 0]
    visualize_correction(os.path.join(IMG_DIR, img_vis))
    break

# %% [markdown]
# ### Data preprocessing

# %%
def apply_clahe(img):
    img_np = np.array(img)
    lab = cv2.cvtColor(img_np, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    l = clahe.apply(l)
    lab = cv2.merge((l,a,b))
    return Image.fromarray(cv2.cvtColor(lab, cv2.COLOR_LAB2RGB))

# %% [markdown]
# ### Find mean and standard Deviation of the images for Normalization

# %%
crop_size = 160
resize_img_dim = (224, 224)

transforms_for_stats = transforms.Compose([
    transforms.Lambda(lambda x: white_balance(x)),         ## Fix the blur
    transforms.Lambda(lambda x: apply_clahe(x)),           ## Brighten dark areas
    transforms.CenterCrop(crop_size),                      ## Crop to focus only on the tonsil area, disregard tongue / teeth
    transforms.Resize(resize_img_dim),                     ## based on ResNet-18, the standard input image dim is (224, 224)
    transforms.ToTensor() 
])

## Creating a dataloader to iterate through the data
stats_dataset = StrepDataset(csv='updated_dataset_120.csv', img_dir=IMG_DIR, transform=transforms_for_stats)
stats_loader = torch.utils.data.DataLoader(stats_dataset, batch_size=84, shuffle=False)

def get_dataset_stats(dataloader):
    pixel_sum = torch.zeros(3)
    pixel_squared_sum = torch.zeros(3)
    batches = 0
    
    for img, _, _ in dataloader:
        pixel_sum += torch.mean(img, dim=[0, 2, 3])              ## averages accross [batch, height, width]
        pixel_squared_sum += torch.mean(img**2, dim=[0, 2, 3])   ## squared averages accross [batch, height, width]
        batches += 1

    mean = pixel_sum/batches
    std = (pixel_squared_sum / batches - mean ** 2) ** 0.5        ## std = (E[X**2] - E[x]**2)**0.5
    return mean, std

custom_mean, custom_std = get_dataset_stats(stats_loader)
print(f"Mean: {custom_mean}") 
print(f"Std: {custom_std}")
# Out:
# C:\Users\avk1028\AppData\Local\Temp\ipykernel_62648\684004477.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   features = torch.tensor(self.data.iloc[idx, 2:9])
# Mean: tensor([0.4321, 0.3801, 0.4037])
# Std: tensor([0.1523, 0.1880, 0.1785])

# %% [markdown]
# ### Verify Normalization

# %%
transforms_temp = transforms.Compose([
    transforms.Lambda(lambda x: white_balance(x)),## Fix the blur
    transforms.Lambda(lambda x: apply_clahe(x)),  ## Brighten dark areas
    transforms.CenterCrop((180,224)),             ## Crop to focus only on the tonsil area, disregard tongue / teeth
    transforms.Resize(resize_img_dim),
    transforms.RandomAffine(degrees=15, translate=(0.1, 0.1), scale=(0.9, 1.1)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    # transforms.Normalize(mean = custom_mean, std= custom_std)
])

temp_dataset = StrepDataset(csv='updated_dataset_120.csv', img_dir=IMG_DIR, transform=transforms_temp)
temp_subset = Subset(temp_dataset, test_idx)
temp_loader = DataLoader(temp_subset, batch_size=1, shuffle=True)

for images, features, labels in temp_loader:

    norm = transforms.Normalize(mean = custom_mean, std= custom_std)
    n_img = images.squeeze(0).float()  # (3, 180, 180)
    norm_img = norm(n_img)
    
    print(f"Image shape: {images.shape}")
    print(f"Mean: {images.squeeze().mean([1, 2])}")
    print(f"Std:  {images.squeeze().std([1, 2])}")

    print(labels)
    min_val, max_val = torch.aminmax(images)
    print(min_val, max_val)

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    
    axes[0].imshow(images.squeeze().permute([1, 2, 0]))
    axes[0].set_title("original")
    axes[0].axis('off')
    
    axes[1].imshow(norm_img.permute([1, 2, 0]))
    axes[1].set_title("normalized")
    axes[1].axis('off')
    
    plt.show()
    break
# Out:
# C:\Users\avk1028\AppData\Local\Temp\ipykernel_62648\684004477.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   features = torch.tensor(self.data.iloc[idx, 2:9])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.5025501..1.9829128].
# Image shape: torch.Size([1, 3, 224, 224])
# Mean: tensor([0.3527, 0.2986, 0.3271])
# Std:  tensor([0.1373, 0.1440, 0.1417])
# tensor([0])
# tensor(0.0510) tensor(0.7529)

# %% [markdown]
# ### Created transforms, Dataloaders for train and test data

# %%
# transforms_train = transforms.Compose([
#     transforms.Lambda(lambda x: white_balance(x)),# 3. Fix the blur
#     # transforms.Lambda(lambda x: extract_throat_roi_otsu(x)),# extract_throat_roi
#     transforms.Lambda(lambda x: apply_clahe(x)),  # 2. Brighten dark areas
#     transforms.CenterCrop(crop_size),                    ## Crop to focus only on the tonsil area, disregard tongue / teeth
#     transforms.Resize(resize_img_dim),
#     # transforms.RandomAffine(degrees=15, translate=(0.1, 0.1), scale=(0.9, 1.1)),
#     transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
#     transforms.ToTensor(),
#     transforms.Normalize(mean = custom_mean, std= custom_std)
# ])

transforms_train = transforms.Compose([
    transforms.Lambda(lambda x: white_balance(x)),
    transforms.Lambda(lambda x: apply_clahe(x)),
    transforms.RandomResizedCrop(resize_img_dim, scale=(0.7, 1.0), ratio=(0.9, 1.1)),
    transforms.RandomRotation(degrees=20),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.05),
    transforms.RandomApply([transforms.GaussianBlur(kernel_size=3)], p=0.3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transforms_test = transforms.Compose([
    transforms.Lambda(lambda x: white_balance(x)),       ## Fix the blur
    transforms.Lambda(lambda x: apply_clahe(x)),         ## Brighten dark areas
    transforms.Resize(resize_img_dim),
    transforms.CenterCrop(crop_size),                    ## Crop to focus only on the tonsil area, disregard tongue / teeth
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

## Created datasets for the train and test data with individual transforms
train_dataset = StrepDataset(csv='updated_dataset_120.csv', img_dir=IMG_DIR, transform=transforms_train)
test_dataset = StrepDataset(csv='updated_dataset_120.csv', img_dir=IMG_DIR, transform=transforms_test)

## Created Subsets for the train and test dataset indices
train_subset = Subset(train_dataset, train_idx)
test_subset = Subset(test_dataset, test_idx)

## Created Dataloaders for the train and test dataset 
train_loader = DataLoader(train_subset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_subset, batch_size=16, shuffle=True)

# %% [markdown]
# ### Train the model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = StrepClassifier(num_features = 7, num_classes = 1).to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001, weight_decay=1e-2)
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-2)
epochs = 50

for epoch in range(epochs):
    model.train()
    
    train_loss = 0.0
    preds_train = 0.0
    correct_train = 0.0
    total_train = 0.0

    for images, features, labels in train_loader:
        images, features, labels = images.to(device), features.to(device), labels.to(device).float()

        optimizer.zero_grad()
        outputs = model(images, features.float()).view(-1) ## [batch_size, 1] -> [batch_size]
        loss = criterion(outputs, labels)
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        optimizer.step()
        train_loss += loss.item()

        preds_train = (outputs > 0).float()
        correct_train += (preds_train == labels).sum().item()
        total_train += labels.size(0)

    train_accuracy = 100 * correct_train / total_train
    print("Epoch:", epoch)
    print("Train loss:", train_loss)
    print(f"Train Acc: {train_accuracy:.2f}%")

    with torch.no_grad(): # Disable gradient calculation to save memory/speed
        val_loss = 0.0
        correct = 0.0
        total = 0.0
        model.eval()
        for images, features, labels in test_loader:
            images, features, labels = images.to(device), features.to(device).float(), labels.to(device).float()
            
            outputs = model(images, features).view(-1)
            val_loss += criterion(outputs, labels).item()
            
            # Convert probabilities to binary predictions (0 or 1)
            preds = (outputs > 0).float()
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    # Print progress
    avg_train_loss = train_loss / len(train_loader)
    avg_val_loss = val_loss / len(test_loader)
    accuracy = 100 * correct / total

    print(f"Epoch [{epoch+1}/{epochs}] "
            f"Train Loss: {avg_train_loss:.4f} | "
            f"Val Loss: {avg_val_loss:.4f} | "
            f"Val Acc: {accuracy:.2f}%")
    print()
# Out:
# C:\Users\avk1028\AppData\Local\Temp\ipykernel_62648\684004477.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   features = torch.tensor(self.data.iloc[idx, 2:9])
# Epoch: 0
# Train loss: 4.640601754188538
# Train Acc: 52.38%
# Epoch [1/50] Train Loss: 0.7734 | Val Loss: 0.9424 | Val Acc: 41.67%
#
# Epoch: 1
# Train loss: 4.638616621494293
# Train Acc: 57.14%
# Epoch [2/50] Train Loss: 0.7731 | Val Loss: 2.3038 | Val Acc: 50.00%
#
# Epoch: 2
# Train loss: 4.334253489971161
# Train Acc: 58.33%
# Epoch [3/50] Train Loss: 0.7224 | Val Loss: 1.7646 | Val Acc: 55.56%
#
# Epoch: 3
# Train loss: 3.5623401403427124
# Train Acc: 59.52%
# Epoch [4/50] Train Loss: 0.5937 | Val Loss: 0.8986 | Val Acc: 61.11%
#
# Epoch: 4
# Train loss: 3.580798387527466
# Train Acc: 71.43%
# Epoch [5/50] Train Loss: 0.5968 | Val Loss: 0.8744 | Val Acc: 55.56%
#
# Epoch: 5
# Train loss: 3.3092730343341827
# Train Acc: 76.19%
# Epoch [6/50] Train Loss: 0.5515 | Val Loss: 0.9599 | Val Acc: 50.00%
#
# Epoch: 6
# Train loss: 3.523246169090271
# Train Acc: 76.19%
# Epoch [7/50] Train Loss: 0.5872 | Val Loss: 1.3568 | Val Acc: 52.78%
#
# Epoch: 7
# Train loss: 2.889268636703491
# Train Acc: 73.81%
# Epoch [8/50] Train Loss: 0.4815 | Val Loss: 0.7943 | Val Acc: 47.22%
#
# Epoch: 8
# Train loss: 3.199085921049118
# Train Acc: 70.24%
# Epoch [9/50] Train Loss: 0.5332 | Val Loss: 0.6963 | Val Acc: 50.00%
#
# Epoch: 9
# Train loss: 2.764344483613968
# Train Acc: 79.76%
# Epoch [10/50] Train Loss: 0.4607 | Val Loss: 0.8611 | Val Acc: 52.78%
#
# Epoch: 10
# Train loss: 2.609917163848877
# Train Acc: 84.52%
# Epoch [11/50] Train Loss: 0.4350 | Val Loss: 0.9948 | Val Acc: 47.22%
#
# Epoch: 11
# Train loss: 2.7889305651187897
# Train Acc: 72.62%
# Epoch [12/50] Train Loss: 0.4648 | Val Loss: 1.2676 | Val Acc: 55.56%
#
# Epoch: 12
# Train loss: 3.960422247648239
# Train Acc: 73.81%
# Epoch [13/50] Train Loss: 0.6601 | Val Loss: 1.2584 | Val Acc: 55.56%
#
# Epoch: 13
# Train loss: 2.3657964020967484
# Train Acc: 79.76%
# Epoch [14/50] Train Loss: 0.3943 | Val Loss: 0.8341 | Val Acc: 61.11%
#
# Epoch: 14
# Train loss: 2.5022087693214417
# Train Acc: 82.14%
# Epoch [15/50] Train Loss: 0.4170 | Val Loss: 0.8066 | Val Acc: 55.56%
#
# Epoch: 15
# Train loss: 2.655594676733017
# Train Acc: 82.14%
# Epoch [16/50] Train Loss: 0.4426 | Val Loss: 0.7939 | Val Acc: 41.67%
#
# Epoch: 16
# Train loss: 3.218780070543289
# Train Acc: 67.86%
# Epoch [17/50] Train Loss: 0.5365 | Val Loss: 0.7689 | Val Acc: 41.67%
#
# Epoch: 17
# Train loss: 2.4628173112869263
# Train Acc: 86.90%
# Epoch [18/50] Train Loss: 0.4105 | Val Loss: 0.8624 | Val Acc: 52.78%
#
# Epoch: 18
# Train loss: 2.2047060430049896
# Train Acc: 88.10%
# Epoch [19/50] Train Loss: 0.3675 | Val Loss: 0.7443 | Val Acc: 52.78%
#
# Epoch: 19
# Train loss: 2.442369222640991
# Train Acc: 83.33%
# Epoch [20/50] Train Loss: 0.4071 | Val Loss: 1.0930 | Val Acc: 52.78%
#
# Epoch: 20
# Train loss: 2.0837028324604034
# Train Acc: 90.48%
# Epoch [21/50] Train Loss: 0.3473 | Val Loss: 0.8719 | Val Acc: 47.22%
#
# Epoch: 21
# Train loss: 2.0447981655597687
# Train Acc: 88.10%
# Epoch [22/50] Train Loss: 0.3408 | Val Loss: 0.7029 | Val Acc: 61.11%
#
# Epoch: 22
# Train loss: 2.1398074328899384
# Train Acc: 86.90%
# Epoch [23/50] Train Loss: 0.3566 | Val Loss: 0.7313 | Val Acc: 61.11%
#
# Epoch: 23
# Train loss: 2.5972629487514496
# Train Acc: 82.14%
# Epoch [24/50] Train Loss: 0.4329 | Val Loss: 1.3087 | Val Acc: 44.44%
#
# Epoch: 24
# Train loss: 2.4456955045461655
# Train Acc: 85.71%
# Epoch [25/50] Train Loss: 0.4076 | Val Loss: 0.9578 | Val Acc: 55.56%
#
# Epoch: 25
# Train loss: 1.9172173887491226
# Train Acc: 94.05%
# Epoch [26/50] Train Loss: 0.3195 | Val Loss: 0.8279 | Val Acc: 55.56%
#
# Epoch: 26
# Train loss: 2.4463537335395813
# Train Acc: 85.71%
# Epoch [27/50] Train Loss: 0.4077 | Val Loss: 0.6546 | Val Acc: 58.33%
#
# Epoch: 27
# Train loss: 2.9598123729228973
# Train Acc: 86.90%
# Epoch [28/50] Train Loss: 0.4933 | Val Loss: 0.8382 | Val Acc: 47.22%
#
# Epoch: 28
# Train loss: 1.8332154899835587
# Train Acc: 89.29%
# Epoch [29/50] Train Loss: 0.3055 | Val Loss: 0.7915 | Val Acc: 52.78%
#
# Epoch: 29
# Train loss: 1.8656318634748459
# Train Acc: 92.86%
# Epoch [30/50] Train Loss: 0.3109 | Val Loss: 0.6694 | Val Acc: 55.56%
#
# Epoch: 30
# Train loss: 2.3714376389980316
# Train Acc: 85.71%
# Epoch [31/50] Train Loss: 0.3952 | Val Loss: 0.8648 | Val Acc: 55.56%
#
# Epoch: 31
# Train loss: 1.5263964980840683
# Train Acc: 94.05%
# Epoch [32/50] Train Loss: 0.2544 | Val Loss: 0.9824 | Val Acc: 50.00%
#
# Epoch: 32
# Train loss: 1.4405032396316528
# Train Acc: 95.24%
# Epoch [33/50] Train Loss: 0.2401 | Val Loss: 1.9248 | Val Acc: 47.22%
#
# Epoch: 33
# Train loss: 1.7577941864728928
# Train Acc: 89.29%
# Epoch [34/50] Train Loss: 0.2930 | Val Loss: 1.0207 | Val Acc: 50.00%
#
# Epoch: 34
# Train loss: 1.6212239861488342
# Train Acc: 92.86%
# Epoch [35/50] Train Loss: 0.2702 | Val Loss: 0.9649 | Val Acc: 47.22%
#
# Epoch: 35
# Train loss: 1.6210757195949554
# Train Acc: 94.05%
# Epoch [36/50] Train Loss: 0.2702 | Val Loss: 0.8537 | Val Acc: 47.22%
#
# Epoch: 36
# Train loss: 2.0991455912590027
# Train Acc: 89.29%
# Epoch [37/50] Train Loss: 0.3499 | Val Loss: 0.9788 | Val Acc: 52.78%
#
# Epoch: 37
# Train loss: 1.7513590306043625
# Train Acc: 86.90%
# Epoch [38/50] Train Loss: 0.2919 | Val Loss: 0.8500 | Val Acc: 52.78%
#
# Epoch: 38
# Train loss: 3.3964382112026215
# Train Acc: 88.10%
# Epoch [39/50] Train Loss: 0.5661 | Val Loss: 1.2373 | Val Acc: 41.67%
#
# Epoch: 39
# Train loss: 2.064488649368286
# Train Acc: 85.71%
# Epoch [40/50] Train Loss: 0.3441 | Val Loss: 0.9724 | Val Acc: 47.22%
#
# Epoch: 40
# Train loss: 1.4656336903572083
# Train Acc: 89.29%
# Epoch [41/50] Train Loss: 0.2443 | Val Loss: 0.9045 | Val Acc: 55.56%
#
# Epoch: 41
# Train loss: 1.6223982721567154
# Train Acc: 92.86%
# Epoch [42/50] Train Loss: 0.2704 | Val Loss: 0.8131 | Val Acc: 58.33%
#
# Epoch: 42
# Train loss: 1.8849663436412811
# Train Acc: 85.71%
# Epoch [43/50] Train Loss: 0.3142 | Val Loss: 1.0322 | Val Acc: 55.56%
#
# Epoch: 43
# Train loss: 1.3088586330413818
# Train Acc: 95.24%
# Epoch [44/50] Train Loss: 0.2181 | Val Loss: 0.9841 | Val Acc: 58.33%
#
# Epoch: 44
# Train loss: 1.4053169339895248
# Train Acc: 92.86%
# Epoch [45/50] Train Loss: 0.2342 | Val Loss: 0.8433 | Val Acc: 55.56%
#
# Epoch: 45
# Train loss: 2.1767459958791733
# Train Acc: 88.10%
# Epoch [46/50] Train Loss: 0.3628 | Val Loss: 0.9830 | Val Acc: 52.78%
#
# Epoch: 46
# Train loss: 1.4846629351377487
# Train Acc: 95.24%
# Epoch [47/50] Train Loss: 0.2474 | Val Loss: 0.9259 | Val Acc: 52.78%
#
# Epoch: 47
# Train loss: 1.6604044735431671
# Train Acc: 88.10%
# Epoch [48/50] Train Loss: 0.2767 | Val Loss: 0.9485 | Val Acc: 47.22%
#
# Epoch: 48
# Train loss: 1.7787693291902542
# Train Acc: 91.67%
# Epoch [49/50] Train Loss: 0.2965 | Val Loss: 1.5946 | Val Acc: 52.78%
#
# Epoch: 49
# Train loss: 1.288560226559639
# Train Acc: 97.62%
# Epoch [50/50] Train Loss: 0.2148 | Val Loss: 1.1966 | Val Acc: 58.33%
